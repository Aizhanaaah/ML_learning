# %%
# !pip install islp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.stats.outliers_influence \
     import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
                         summarize,
                         poly)

# %%
#a
np.random.seed(1)
X = np.random.normal(0, 1, 100)

# %%
#b
eps = np.random.normal(0, 0.25, 100)
eps.mean()
eps.var()
# Out:
# np.float64(0.05428839623518566)

# %%
#c
Y = -1 + 0.5*X + eps
len(Y)
intercept = -1
slope = 0.5

# %%
#d
X_raw = X[:, 1]
plt.scatter(X_raw, Y, color='blue', marker='o')
plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Relationship between X and Y')
plt.show()

# %%
#e
X = sm.add_constant(X) 
model = sm.OLS(Y, X)
result = model.fit()
result.summary()
result.params

for i, name in enumerate(['Intercept', 'Slope']):
    print(f"Estimated {name} (beta_{i}):", result.params[i])
# Out:
# Estimated Intercept (beta_0): -0.9632466175754494
# Estimated Slope (beta_1): 0.523856783412793

# %%
#f
plt.scatter(X_raw, Y, color='#FF7F50', marker='*', label="Data points")
plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Relationship between X and Y')
plt.legend(loc='upper left', fontsize='small', title='Legend')
plt.show()
